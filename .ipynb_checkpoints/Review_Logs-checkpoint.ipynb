# %% [markdown]
# # Importing Libraries

# %%
import os
import json
import pandas as pd
import numpy as np

# %%
folder_path = 'C:/Users/Prajwal/Desktop/BUAN_6341_Applied_Machine_Learning/Cricket/Tests_2011_Present/'
#folder_path = 'C:/Users/Prajwal/Desktop/BUAN_6341_Applied_Machine_Learning/Cricket/Sample/'
all_data = []

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    #print(file_path)
    
    with open(file_path, 'r', encoding='utf-8') as file: # Open and load each JSON file
        data = json.load(file)
        all_data.append(data)  # Append loaded data to the list

print(f"Loaded {len(all_data)} files successfully.")
# Out:
# Loaded 592 files successfully.

# %%
print(all_data[0]['info']['event']['name'])
# Out:
# South Africa in Australia Test Series

# %% [markdown]
# Viewing innings of some random match below.

# %%
all_data[2]['innings']
# Out:
# [{'team': 'South Africa',
#   'overs': [{'over': 0,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 1,
#     'deliveries': [{'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 2,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'extras': {'noballs': 1},
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 3,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 4,
#     'deliveries': [{'batter': 'D Elgar',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 5,
#     'deliveries': [{'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 6,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'D Elgar',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'D Elgar',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'D Elgar',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'D Elgar',
#         'fielders': [{'name': 'UT Khawaja'}]}]},
#      {'batter': 'HM Amla',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 7,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 8,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'extras': {'legbyes': 4},
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 4, 'total': 4}}]},
#    {'over': 9,
#     'deliveries': [{'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 10,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'HM Amla',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'HM Amla',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#    {'over': 11,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'HM Amla',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'HM Amla',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 12,
#     'deliveries': [{'batter': 'HM Amla',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'HM Amla',
#         'fielders': [{'name': 'MT Renshaw'}]}]},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 13,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'JP Duminy',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'JP Duminy',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'JP Duminy',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'JP Duminy',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'JP Duminy',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 14,
#     'deliveries': [{'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'JP Duminy',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'JP Duminy',
#         'fielders': [{'name': 'MS Wade'}]}]},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 15,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 16,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 17,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 18,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 19,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 20,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 21,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 22,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 23,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'extras': {'byes': 3},
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 3, 'total': 3}},
#      {'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 24,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 25,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 26,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 27,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 28,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 29,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 30,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 31,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'SC Cook',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 32,
#     'deliveries': [{'batter': 'SC Cook',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'SC Cook',
#         'fielders': [{'name': 'SPD Smith'}]}]},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#    {'over': 33,
#     'deliveries': [{'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#    {'over': 34,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 35,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 36,
#     'deliveries': [{'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'T Bavuma',
#       'bowler': 'MA Starc',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 37,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 38,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 39,
#     'deliveries': [{'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 40,
#     'deliveries': [{'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 41,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'T Bavuma',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'T Bavuma',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 42,
#     'deliveries': [{'batter': 'T Bavuma',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'T Bavuma',
#         'fielders': [{'name': 'MS Wade'}]}]},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 43,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 44,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 45,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 46,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JM Bird',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JM Bird',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 47,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 48,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 49,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'NM Lyon',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'F du Plessis',
#       'bowler': 'NM Lyon',
#       'non_striker': 'Q de Kock',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 50,
#     'deliveries': [{'batter': 'Q de Kock',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'Q de Kock',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'Q de Kock',
#         'fielders': [{'name': 'MS Wade'}]}]},
#      {'batter': 'VD Philander',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'VD Philander',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'VD Philander',
#       'bowler': 'JR Hazlewood',
#       'non_striker': 'F du Plessis',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 51,
#     'deliveries': [{'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'VD Philander',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'VD Philander',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'F du Plessis',
#       'bowler': 'MA Starc',
#       'non_striker': 'VD Philander',
# ...
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 24,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#    {'over': 25,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'review': {'by': 'South Africa',
#        'umpire': 'RA Kettleborough',
#        'batter': 'MT Renshaw',
#        'decision': 'struck down'},
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'VD Philander',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 26,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 27,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 28,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 29,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 30,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#    {'over': 31,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 32,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#    {'over': 33,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'K Rabada',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 34,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 35,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'K Rabada',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 36,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 37,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 38,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'SPD Smith',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'SPD Smith',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#    {'over': 39,
#     'deliveries': [{'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#      {'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#      {'batter': 'SPD Smith',
#       'bowler': 'KJ Abbott',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0},
#       'wickets': [{'kind': 'caught',
#         'player_out': 'SPD Smith',
#         'fielders': [{'name': 'Q de Kock'}]}]}]},
#    {'over': 40,
#     'deliveries': [{'batter': 'MT Renshaw',
#       'bowler': 'T Shamsi',
#       'non_striker': 'PSP Handscomb',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#      {'batter': 'PSP Handscomb',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'PSP Handscomb',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'PSP Handscomb',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#      {'batter': 'PSP Handscomb',
#       'bowler': 'T Shamsi',
#       'non_striker': 'MT Renshaw',
#       'runs': {'batter': 1, 'extras': 0, 'total': 1}}]}]}]

# %% [markdown]
# ### Checking if any file has missing event key.

# %%
for i in range(len(all_data)):
    event = all_data[i]['info'].get('event')
    
    if event:
        print(event)
    else:
        print(f"File {i} missing 'event' key.")
# Out:
# {'match_number': 1, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 2, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 3, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Australia Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Australia Test Series'}
# {'match_number': 3, 'name': 'Pakistan in Australia Test Series'}
# {'match_number': 1, 'name': 'Bangladesh in New Zealand Test Series'}
# {'match_number': 2, 'name': 'Bangladesh in New Zealand Test Series'}
# {'match_number': 1, 'name': 'Pakistan in New Zealand Test Series'}
# {'match_number': 2, 'name': 'Pakistan in New Zealand Test Series'}
# {'match_number': 1, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 2, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 3, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 1, 'name': 'India in West Indies Test Series'}
# {'match_number': 2, 'name': 'India in West Indies Test Series'}
# {'match_number': 3, 'name': 'India in West Indies Test Series'}
# {'match_number': 4, 'name': 'India in West Indies Test Series'}
# {'match_number': 1, 'name': 'New Zealand in Zimbabwe Test Series'}
# {'match_number': 2, 'name': 'New Zealand in Zimbabwe Test Series'}
# {'match_number': 1, 'name': 'England in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'England in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'New Zealand in India Test Series'}
# {'match_number': 2, 'name': 'New Zealand in India Test Series'}
# {'match_number': 3, 'name': 'New Zealand in India Test Series'}
# {'match_number': 1, 'name': "Basil D'Oliveira Trophy"}
# {'name': 'South Africa tour of England', 'match_number': 2}
# {'name': 'South Africa tour of England', 'match_number': 3}
# {'name': 'South Africa tour of England', 'match_number': 4}
# {'name': 'West Indies tour of England', 'match_number': 1}
# {'name': 'West Indies tour of England', 'match_number': 2}
# {'name': 'West Indies tour of England', 'match_number': 3}
# {'match_number': 1, 'name': 'England in India Test Series'}
# {'match_number': 2, 'name': 'England in India Test Series'}
# {'match_number': 3, 'name': 'England in India Test Series'}
# {'match_number': 4, 'name': 'England in India Test Series'}
# {'match_number': 5, 'name': 'England in India Test Series'}
# {'name': 'Bangladesh tour of India', 'match_number': 1}
# {'match_number': 1, 'name': 'Pakistan v West Indies Test Series'}
# {'match_number': 2, 'name': 'Pakistan v West Indies Test Series'}
# {'match_number': 3, 'name': 'Pakistan v West Indies Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in Zimbabwe Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in Zimbabwe Test Series'}
# {'match_number': 1, 'name': 'Australia in India Test Series'}
# {'match_number': 2, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 3, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 4, 'name': 'Border-Gavaskar Trophy'}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 1}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 2}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 3}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 4}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 5}
# {'name': 'Bangladesh tour of South Africa', 'match_number': 1}
# {'name': 'Bangladesh tour of South Africa', 'match_number': 2}
# {'name': 'Australia tour of South Africa', 'match_number': 1}
# {'name': 'Australia tour of South Africa', 'match_number': 2}
# {'name': 'Australia tour of South Africa', 'match_number': 3}
# {'name': 'Australia tour of South Africa', 'match_number': 4}
# {'match_number': 1, 'name': 'Pakistan in West Indies Test Series'}
# {'match_number': 2, 'name': 'Pakistan in West Indies Test Series'}
# {'match_number': 3, 'name': 'Pakistan in West Indies Test Series'}
# {'match_number': 1, 'name': 'Bangladesh in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Bangladesh in Sri Lanka Test Series'}
# {'name': "Women's Ashes"}
# {'name': 'Australia tour of Bangladesh', 'match_number': 1}
# {'name': 'Australia tour of Bangladesh', 'match_number': 2}
# {'name': 'Zimbabwe tour of Sri Lanka'}
# {'name': 'India tour of Sri Lanka', 'match_number': 1}
# {'name': 'India tour of Sri Lanka', 'match_number': 2}
# {'name': 'India tour of Sri Lanka', 'match_number': 3}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 1}
# {'name': 'England tour of Australia and New Zealand', 'match_number': 2}
# {'name': 'West Indies tour of New Zealand', 'match_number': 1}
# {'name': 'West Indies tour of New Zealand', 'match_number': 2}
# {'name': 'Pakistan tour of Ireland, England and Scotland', 'match_number': 1}
# {'name': 'Pakistan tour of Ireland, England and Scotland', 'match_number': 2}
# {'name': 'India tour of Ireland and England', 'match_number': 1}
# {'name': 'India tour of Ireland and England', 'match_number': 2}
# {'name': 'India tour of Ireland and England', 'match_number': 3}
# {'name': 'India tour of Ireland and England', 'match_number': 4}
# {'name': 'India tour of Ireland and England', 'match_number': 5}
# {'name': 'Sri Lanka tour of United Arab Emirates and Pakistan', 'match_number': 1}
# {'name': 'Sri Lanka tour of United Arab Emirates and Pakistan', 'match_number': 2}
# {'name': 'India tour of South Africa', 'match_number': 1}
# {'name': 'India tour of South Africa', 'match_number': 2}
# {'name': 'India tour of South Africa', 'match_number': 3}
# {'name': 'Zimbabwe tour of South Africa'}
# {'name': 'Sri Lanka tour of India', 'match_number': 1}
# {'name': 'Sri Lanka tour of India', 'match_number': 2}
# {'name': 'Sri Lanka tour of India', 'match_number': 3}
# {'name': 'West Indies tour of Zimbabwe', 'match_number': 1}
# {'name': 'West Indies tour of Zimbabwe', 'match_number': 2}
# {'name': 'Pakistan tour of Ireland, England and Scotland'}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 1}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 2}
# {'name': 'Sri Lanka tour of West Indies', 'match_number': 1}
# {'name': 'Sri Lanka tour of West Indies', 'match_number': 2}
# {'name': 'Sri Lanka tour of West Indies', 'match_number': 3}
# {'name': 'England tour of Sri Lanka', 'match_number': 1}
# {'name': 'England tour of Sri Lanka', 'match_number': 2}
# {'name': 'England tour of Sri Lanka', 'match_number': 3}
# {'name': 'South Africa tour of Sri Lanka', 'match_number': 1}
# {'name': 'South Africa tour of Sri Lanka', 'match_number': 2}
# {'name': 'Pakistan tour of South Africa', 'match_number': 1}
# {'name': 'Pakistan tour of South Africa', 'match_number': 2}
# {'name': 'Pakistan tour of South Africa', 'match_number': 3}
# {'name': 'Sri Lanka tour of South Africa', 'match_number': 1}
# {'name': 'Sri Lanka tour of South Africa', 'match_number': 2}
# {'name': 'India tour of Australia', 'match_number': 1}
# {'name': 'India tour of Australia', 'match_number': 2}
# {'name': 'India tour of Australia', 'match_number': 3}
# {'name': 'India tour of Australia', 'match_number': 4}
# {'name': 'Sri Lanka tour of Australia', 'match_number': 1}
# {'name': 'Sri Lanka tour of Australia', 'match_number': 2}
# {'name': 'Bangladesh tour of West Indies and United States of America', 'match_number': 1}
# {'name': 'Bangladesh tour of West Indies and United States of America', 'match_number': 2}
# {'name': 'Ireland tour of England'}
# {'name': 'The Ashes', 'match_number': 1}
# {'name': 'The Ashes', 'match_number': 2}
# {'name': 'The Ashes', 'match_number': 3}
# {'name': 'The Ashes', 'match_number': 4}
# {'name': 'The Ashes', 'match_number': 5}
# {'name': 'West Indies tour of Bangladesh', 'match_number': 1}
# {'name': 'West Indies tour of Bangladesh', 'match_number': 2}
# {'name': 'Zimbabwe tour of Bangladesh', 'match_number': 1}
# {'name': 'Zimbabwe tour of Bangladesh', 'match_number': 2}
# {'name': 'Sri Lanka tour of New Zealand', 'match_number': 1}
# {'name': 'Sri Lanka tour of New Zealand', 'match_number': 2}
# {'name': 'Bangladesh tour of New Zealand', 'match_number': 1}
# {'name': 'Bangladesh tour of New Zealand', 'match_number': 2}
# {'name': 'Australia tour of United Arab Emirates', 'match_number': 1}
# {'name': 'Australia tour of United Arab Emirates', 'match_number': 2}
# {'name': 'New Zealand tour of United Arab Emirates', 'match_number': 1}
# {'name': 'New Zealand tour of United Arab Emirates', 'match_number': 2}
# {'name': 'New Zealand tour of United Arab Emirates', 'match_number': 3}
# {'name': 'West Indies tour of India', 'match_number': 1}
# {'name': 'West Indies tour of India', 'match_number': 2}
# {'name': 'England tour of West Indies', 'match_number': 1}
# {'name': 'England tour of West Indies', 'match_number': 2}
# {'name': 'England tour of West Indies', 'match_number': 3}
# {'name': 'Australia Women tour of England'}
# {'name': 'Pakistan in Australia Test Series', 'match_number': 1}
# {'name': 'Pakistan in Australia Test Series', 'match_number': 2}
# {'name': 'Trans-Tasman Trophy', 'match_number': 1}
# {'name': 'Trans-Tasman Trophy', 'match_number': 2}
# {'name': 'Trans-Tasman Trophy', 'match_number': 3}
# {'name': "Basil D'Oliveira Trophy", 'match_number': 1}
# {'name': "Basil D'Oliveira Trophy", 'match_number': 2}
# {'name': "Basil D'Oliveira Trophy", 'match_number': 3}
# {'name': "Basil D'Oliveira Trophy", 'match_number': 4}
# {'name': 'South Africa in India Test Series', 'match_number': 1}
# {'name': 'South Africa in India Test Series', 'match_number': 2}
# {'name': 'South Africa in India Test Series', 'match_number': 3}
# {'name': 'Bangladesh in India Test Series', 'match_number': 1}
# {'name': 'Bangladesh in India Test Series', 'match_number': 2}
# {'name': 'England in New Zealand Test Series', 'match_number': 1}
# {'name': 'England in New Zealand Test Series', 'match_number': 2}
# {'name': 'India in New Zealand Test Series', 'match_number': 1}
# {'name': 'India in New Zealand Test Series', 'match_number': 2}
# {'name': 'India in West Indies Test Series', 'match_number': 1}
# {'name': 'India in West Indies Test Series', 'match_number': 2}
# {'name': 'New Zealand in Sri Lanka Test Series', 'match_number': 1}
# {'name': 'New Zealand in Sri Lanka Test Series', 'match_number': 2}
# {'name': 'Pakistan tour of England', 'match_number': 1}
# {'name': 'Pakistan tour of England', 'match_number': 2}
# {'name': 'Pakistan tour of England', 'match_number': 3}
# {'name': 'Sri Lanka in Pakistan Test Series', 'match_number': 1}
# {'name': 'Sri Lanka in Pakistan Test Series', 'match_number': 2}
# {'name': 'Sri Lanka tour of Zimbabwe', 'match_number': 1}
# {'name': 'Sri Lanka tour of Zimbabwe', 'match_number': 2}
# {'name': 'Bangladesh in Pakistan Test Series', 'match_number': 1}
# {'name': 'Zimbabwe tour of Bangladesh'}
# {'name': 'India tour of Australia', 'match_number': 1}
# {'name': 'India tour of Australia', 'match_number': 2}
# {'name': 'India tour of Australia', 'match_number': 3}
# {'name': 'India tour of Australia', 'match_number': 4}
# {'name': 'West Indies tour of England', 'match_number': 1}
# {'name': 'West Indies tour of England', 'match_number': 2}
# {'name': 'West Indies tour of England', 'match_number': 3}
# {'name': 'West Indies tour of New Zealand', 'match_number': 1}
# {'name': 'West Indies tour of New Zealand', 'match_number': 2}
# {'name': 'Pakistan tour of New Zealand', 'match_number': 1}
# {'name': 'Pakistan tour of New Zealand', 'match_number': 2}
# {'name': 'Sri Lanka tour of South Africa', 'match_number': 1}
# {'name': 'Sri Lanka tour of South Africa', 'match_number': 2}
# {'name': 'India tour of England', 'match_number': 1}
# {'name': 'India tour of England', 'match_number': 2}
# {'name': 'India tour of England', 'match_number': 3}
# {'name': 'India tour of England', 'match_number': 4}
# {'name': 'England tour of Sri Lanka', 'match_number': 1}
# {'name': 'England tour of Sri Lanka', 'match_number': 2}
# {'name': 'South Africa tour of Pakistan', 'match_number': 1}
# {'name': 'South Africa tour of Pakistan', 'match_number': 2}
# {'name': 'England tour of India', 'match_number': 1}
# {'name': 'England tour of India', 'match_number': 2}
# {'name': 'England tour of India', 'match_number': 3}
# {'name': 'England tour of India', 'match_number': 4}
# {'name': 'West Indies tour of Bangladesh', 'match_number': 1}
# {'name': 'West Indies tour of Bangladesh', 'match_number': 2}
# {'name': 'New Zealand tour of England', 'match_number': 1}
# {'name': 'New Zealand tour of England', 'match_number': 2}
# {'name': 'ICC World Test Championship', 'stage': 'Final'}
# {'name': 'Sri Lanka tour of West Indies', 'match_number': 1}
# {'name': 'Sri Lanka tour of West Indies', 'match_number': 2}
# {'name': 'Sri Lanka v Bangladesh', 'match_number': 1}
# {'name': 'Bangladesh tour of Sri Lanka', 'match_number': 2}
# {'name': 'England tour of West Indies', 'match_number': 1}
# {'name': 'England tour of West Indies', 'match_number': 2}
# {'name': 'England tour of West Indies', 'match_number': 3}
# {'name': 'Pakistan tour of Zimbabwe', 'match_number': 1}
# {'name': 'Pakistan tour of Zimbabwe', 'match_number': 2}
# {'name': 'India Women tour of England'}
# {'name': 'South Africa tour of West Indies', 'match_number': 1}
# {'name': 'South Africa tour of West Indies', 'match_number': 2}
# {'name': 'Pakistan tour of West Indies', 'match_number': 1}
# {'name': 'Pakistan tour of West Indies', 'match_number': 2}
# {'name': 'The Ashes', 'match_number': 1}
# {'name': 'The Ashes', 'match_number': 2}
# {'name': 'The Ashes', 'match_number': 3}
# {'name': 'The Ashes', 'match_number': 4}
# {'name': 'The Ashes', 'match_number': 5}
# {'name': "Women's Ashes"}
# {'name': 'India Women tour of Australia'}
# {'name': 'Bangladesh tour of Zimbabwe'}
# {'name': 'New Zealand tour of England', 'match_number': 1}
# {'name': 'New Zealand tour of England', 'match_number': 2}
# {'name': 'New Zealand tour of England', 'match_number': 3}
# {'name': 'South Africa tour of England', 'match_number': 1}
# {'name': 'South Africa tour of England', 'match_number': 2}
# {'name': 'South Africa tour of England', 'match_number': 3}
# {'name': 'India tour of South Africa', 'match_number': 1}
# {'name': 'India tour of South Africa', 'match_number': 2}
# {'name': 'India tour of South Africa', 'match_number': 3}
# {'name': 'Bangladesh tour of South Africa', 'match_number': 1}
# {'name': 'Bangladesh tour of South Africa', 'match_number': 2}
# {'name': 'Pakistan tour of Bangladesh', 'match_number': 1}
# {'name': 'Pakistan tour of Bangladesh', 'match_number': 2}
# {'name': 'New Zealand tour of India', 'match_number': 1}
# {'name': 'New Zealand tour of India', 'match_number': 2}
# {'name': 'Sri Lanka tour of India', 'match_number': 1}
# {'name': 'Sri Lanka tour of India', 'match_number': 2}
# {'name': 'Australia tour of Pakistan', 'match_number': 1}
# {'name': 'Australia tour of Pakistan', 'match_number': 2}
# {'name': 'Australia tour of Pakistan', 'match_number': 3}
# {'name': 'West Indies tour of Sri Lanka', 'match_number': 1}
# {'name': 'West Indies tour of Sri Lanka', 'match_number': 2}
# {'name': 'Bangladesh tour of New Zealand', 'match_number': 1}
# {'name': 'Bangladesh tour of New Zealand', 'match_number': 2}
# {'name': 'South Africa tour of New Zealand', 'match_number': 1}
# {'name': 'South Africa tour of New Zealand', 'match_number': 2}
# {'name': 'South Africa Women tour of England'}
# {'name': 'Australia tour of Sri Lanka', 'match_number': 1}
# {'name': 'Australia tour of Sri Lanka', 'match_number': 2}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 1}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 2}
# {'name': 'Bangladesh tour of West Indies', 'match_number': 1}
# {'name': 'Bangladesh tour of West Indies', 'match_number': 2}
# {'name': 'West Indies tour of Australia', 'match_number': 1}
# {'name': 'West Indies tour of Australia', 'match_number': 2}
# {'name': 'South Africa tour of Australia', 'match_number': 1}
# {'name': 'South Africa tour of Australia', 'match_number': 2}
# {'name': 'South Africa tour of Australia', 'match_number': 3}
# {'name': 'India tour of England', 'match_number': 5}
# {'name': 'Pakistan tour of Sri Lanka', 'match_number': 1}
# {'name': 'Pakistan tour of Sri Lanka', 'match_number': 2}
# {'name': 'England tour of New Zealand', 'match_number': 1}
# {'name': 'England tour of New Zealand', 'match_number': 2}
# {'name': 'Sri Lanka tour of New Zealand', 'match_number': 1}
# {'name': 'Sri Lanka tour of New Zealand', 'match_number': 2}
# {'name': 'England tour of Pakistan', 'match_number': 1}
# {'name': 'England tour of Pakistan', 'match_number': 2}
# {'name': 'England tour of Pakistan', 'match_number': 3}
# {'name': 'The Ashes', 'match_number': 1}
# {'name': 'The Ashes', 'match_number': 2}
# {'name': 'The Ashes', 'match_number': 3}
# {'name': 'The Ashes', 'match_number': 4}
# {'name': 'The Ashes', 'match_number': 5}
# {'name': "Women's Ashes"}
# {'name': 'Ireland tour of England'}
# {'name': 'West Indies tour of South Africa', 'match_number': 1}
# {'name': 'West Indies tour of South Africa', 'match_number': 2}
# {'name': 'New Zealand tour of Pakistan', 'match_number': 1}
# {'name': 'New Zealand tour of Pakistan', 'match_number': 2}
# {'name': 'India tour of Bangladesh', 'match_number': 1}
# {'name': 'India tour of Bangladesh', 'match_number': 2}
# {'name': 'Australia tour of India', 'match_number': 1}
# {'name': 'Australia tour of India', 'match_number': 2}
# {'name': 'Australia tour of India', 'match_number': 3}
# {'name': 'Australia tour of India', 'match_number': 4}
# {'name': 'West Indies tour of Zimbabwe', 'match_number': 1}
# {'name': 'West Indies tour of Zimbabwe', 'match_number': 2}
# {'name': 'Ireland tour of Bangladesh'}
# {'name': 'ICC World Test Championship', 'stage': 'Final'}
# {'name': 'Ireland tour of Sri Lanka', 'match_number': 1}
# {'name': 'Ireland tour of Sri Lanka', 'match_number': 2}
# {'name': 'Pakistan tour of Australia', 'match_number': 1}
# {'name': 'Pakistan tour of Australia', 'match_number': 2}
# {'name': 'Pakistan tour of Australia', 'match_number': 3}
# {'name': 'West Indies tour of Australia', 'match_number': 1}
# {'name': 'West Indies tour of Australia', 'match_number': 2}
# {'name': 'South Africa Women tour of Australia'}
# {'name': 'India tour of West Indies', 'match_number': 1}
# {'name': 'India tour of West Indies', 'match_number': 2}
# {'name': 'Pakistan tour of Sri Lanka', 'match_number': 1}
# {'name': 'Pakistan tour of Sri Lanka', 'match_number': 2}
# {'name': 'West Indies tour of England', 'match_number': 1}
# {'name': 'West Indies tour of England', 'match_number': 2}
# {'name': 'West Indies tour of England', 'match_number': 3}
# {'name': 'Sri Lanka tour of England', 'match_number': 1}
# {'name': 'Sri Lanka tour of England', 'match_number': 2}
# {'name': 'Sri Lanka tour of England', 'match_number': 3}
# {'name': 'India tour of South Africa', 'match_number': 1}
# {'name': 'India tour of South Africa', 'match_number': 2}
# {'name': 'South Africa tour of New Zealand', 'match_number': 1}
# {'name': 'South Africa tour of New Zealand', 'match_number': 2}
# {'name': 'Australia tour of New Zealand', 'match_number': 1}
# {'name': 'Australia tour of New Zealand', 'match_number': 2}
# {'name': 'England tour of India', 'match_number': 1}
# {'name': 'England tour of India', 'match_number': 2}
# {'name': 'England tour of India', 'match_number': 3}
# {'name': 'England tour of India', 'match_number': 4}
# {'name': 'England tour of India', 'match_number': 5}
# {'name': 'New Zealand tour of Bangladesh', 'match_number': 1}
# {'name': 'New Zealand tour of Bangladesh', 'match_number': 2}
# {'name': 'England Women tour of India'}
# {'name': 'Australia Women tour of India'}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 1}
# {'name': 'Sri Lanka tour of Bangladesh', 'match_number': 2}
# {'name': 'India tour of Australia', 'match_number': 1}
# {'name': 'England tour of New Zealand', 'match_number': 1}
# {'name': 'Zimbabwe tour of Ireland'}
# {'name': 'Sri Lanka tour of South Africa', 'match_number': 1}
# {'name': 'South Africa tour of West Indies', 'match_number': 1}
# {'name': 'South Africa tour of West Indies', 'match_number': 2}
# {'name': 'Bangladesh tour of West Indies', 'match_number': 1}
# {'name': 'Bangladesh tour of West Indies', 'match_number': 2}
# {'name': 'South Africa Women tour of India'}
# {'name': 'Bangladesh tour of India', 'match_number': 1}
# {'name': 'Bangladesh tour of India', 'match_number': 2}
# {'name': 'New Zealand tour of India', 'match_number': 1}
# {'name': 'New Zealand tour of India', 'match_number': 2}
# {'name': 'New Zealand tour of India', 'match_number': 3}
# {'name': 'Bangladesh tour of Pakistan', 'match_number': 1}
# {'name': 'Bangladesh tour of Pakistan', 'match_number': 2}
# {'name': 'England tour of Pakistan', 'match_number': 1}
# {'name': 'England tour of Pakistan', 'match_number': 2}
# {'name': 'England tour of Pakistan', 'match_number': 3}
# {'name': 'New Zealand tour of Sri Lanka', 'match_number': 1}
# {'name': 'New Zealand tour of Sri Lanka', 'match_number': 2}
# {'name': 'South Africa tour of Bangladesh', 'match_number': 1}
# {'name': 'South Africa tour of Bangladesh', 'match_number': 2}
# {'match_number': 2, 'name': 'India in South Africa Test Series'}
# {'match_number': 3, 'name': 'India in South Africa Test Series'}
# {'match_number': 1, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 2, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 1, 'name': 'New Zealand in India Test Series'}
# {'match_number': 2, 'name': 'New Zealand in India Test Series'}
# {'match_number': 3, 'name': 'New Zealand in India Test Series'}
# {'match_number': 1, 'name': 'West Indies in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'West Indies in Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'West Indies in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Pakistan in New Zealand Test Series'}
# {'match_number': 2, 'name': 'Pakistan in New Zealand Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 3, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 1, 'name': 'Pataudi Trophy'}
# {'match_number': 2, 'name': 'Pataudi Trophy'}
# {'match_number': 3, 'name': 'Pataudi Trophy'}
# {'match_number': 4, 'name': 'Pataudi Trophy'}
# {'name': 'England Women tour of Australia'}
# {'match_number': 1, 'name': 'Pakistan in West Indies Test Series'}
# {'match_number': 2, 'name': 'Pakistan in West Indies Test Series'}
# {'match_number': 1, 'name': 'India in West Indies Test Series'}
# {'match_number': 2, 'name': 'India in West Indies Test Series'}
# {'match_number': 3, 'name': 'India in West Indies Test Series'}
# {'match_number': 1, 'name': 'Australia in South Africa Test Series'}
# {'match_number': 2, 'name': 'Australia in South Africa Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 3, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 1, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 2, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 3, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 1, 'name': 'Trans-Tasman Trophy'}
# {'match_number': 2, 'name': 'Trans-Tasman Trophy'}
# {'match_number': 1, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 2, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 3, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 4, 'name': 'Border-Gavaskar Trophy'}
# {'name': 'Zimbabwe tour of New Zealand', 'match_number': 1}
# {'match_number': 1, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 2, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 3, 'name': 'South Africa in New Zealand Test Series'}
# {'match_number': 1, 'name': 'England in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'England in Sri Lanka Test Series'}
# {'name': 'Bangladesh tour of Zimbabwe', 'match_number': 1}
# {'name': 'Pakistan tour of Zimbabwe', 'match_number': 1}
# {'name': 'New Zealand tour of Zimbabwe', 'match_number': 1}
# {'match_number': 1, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Pakistan v England Test Series'}
# {'match_number': 2, 'name': 'Pakistan v England Test Series'}
# {'match_number': 3, 'name': 'Pakistan v England Test Series'}
# {'match_number': 1, 'name': 'West Indies in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'West Indies in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'The Wisden Trophy'}
# {'match_number': 2, 'name': 'The Wisden Trophy'}
# {'match_number': 3, 'name': 'The Wisden Trophy'}
# {'match_number': 1, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 2, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 3, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 1, 'name': 'West Indies in India Test Series'}
# {'match_number': 2, 'name': 'West Indies in India Test Series'}
# {'match_number': 3, 'name': 'West Indies in India Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 2, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 3, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 1, 'name': 'New Zealand in West Indies Test Series'}
# {'match_number': 2, 'name': 'New Zealand in West Indies Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'England in India Test Series'}
# {'match_number': 2, 'name': 'England in India Test Series'}
# {'match_number': 3, 'name': 'England in India Test Series'}
# {'match_number': 4, 'name': 'England in India Test Series'}
# {'match_number': 1, 'name': 'New Zealand in India Test Series'}
# {'match_number': 2, 'name': 'New Zealand in India Test Series'}
# {'match_number': 1, 'name': 'New Zealand in England Test Series'}
# {'match_number': 2, 'name': 'New Zealand in England Test Series'}
# {'match_number': 1, 'name': 'The Ashes'}
# {'match_number': 2, 'name': 'The Ashes'}
# {'match_number': 3, 'name': 'The Ashes'}
# {'match_number': 4, 'name': 'The Ashes'}
# {'match_number': 5, 'name': 'The Ashes'}
# {'match_number': 1, 'name': 'New Zealand in South Africa Test Series'}
# {'match_number': 2, 'name': 'New Zealand in South Africa Test Series'}
# {'match_number': 1, 'name': 'Pakistan in South Africa Test Series'}
# {'match_number': 2, 'name': 'Pakistan in South Africa Test Series'}
# {'match_number': 3, 'name': 'Pakistan in South Africa Test Series'}
# {'match_number': 1, 'name': 'England in New Zealand Test Series'}
# {'match_number': 2, 'name': 'England in New Zealand Test Series'}
# {'match_number': 3, 'name': 'England in New Zealand Test Series'}
# {'match_number': 1, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 2, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 3, 'name': 'South Africa in Australia Test Series'}
# {'match_number': 1, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 2, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 3, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 1, 'name': 'New Zealand in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'New Zealand in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'West Indies in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'West Indies in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'The Ashes'}
# {'match_number': 2, 'name': 'The Ashes'}
# {'match_number': 3, 'name': 'The Ashes'}
# {'match_number': 4, 'name': 'The Ashes'}
# {'match_number': 5, 'name': 'The Ashes'}
# {'name': "Women's Ashes"}
# {'match_number': 1, 'name': 'Clive Lloyd Trophy'}
# {'match_number': 2, 'name': 'Clive Lloyd Trophy'}
# {'match_number': 1, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 2, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 3, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 4, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 1, 'name': 'Bangladesh in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Bangladesh in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Bangladesh in Zimbabwe Test Series'}
# {'match_number': 2, 'name': 'Bangladesh in Zimbabwe Test Series'}
# {'match_number': 1, 'name': 'India in South Africa Test Series'}
# {'match_number': 2, 'name': 'India in South Africa Test Series'}
# {'match_number': 1, 'name': 'Australia in South Africa Test Series'}
# {'match_number': 2, 'name': 'Australia in South Africa Test Series'}
# {'match_number': 3, 'name': 'Australia in South Africa Test Series'}
# {'match_number': 1, 'name': 'Pakistan v South Africa Test Series'}
# {'match_number': 2, 'name': 'Pakistan v South Africa Test Series'}
# {'match_number': 1, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'Pakistan v Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Zimbabwe Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Zimbabwe Test Series'}
# {'match_number': 1, 'name': 'West Indies in New Zealand Test Series'}
# {'match_number': 2, 'name': 'West Indies in New Zealand Test Series'}
# {'match_number': 3, 'name': 'West Indies in New Zealand Test Series'}
# {'match_number': 1, 'name': 'India in New Zealand Test Series'}
# {'match_number': 2, 'name': 'India in New Zealand Test Series'}
# {'match_number': 1, 'name': 'Pataudi Trophy'}
# {'match_number': 2, 'name': 'Pataudi Trophy'}
# {'match_number': 3, 'name': 'Pataudi Trophy'}
# {'match_number': 4, 'name': 'Pataudi Trophy'}
# {'match_number': 5, 'name': 'Pataudi Trophy'}
# {'match_number': 1, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 1, 'name': 'New Zealand in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'New Zealand in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'West Indies in India Test Series'}
# {'match_number': 2, 'name': 'West Indies in India Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'Sir Vivian Richards Trophy'}
# {'match_number': 2, 'name': 'Sir Vivian Richards Trophy'}
# {'match_number': 3, 'name': 'Sir Vivian Richards Trophy'}
# {'name': 'India Women tour of England', 'match_number': 1}
# {'match_number': 1, 'name': 'Pakistan v Australia Test Series'}
# {'match_number': 2, 'name': 'Pakistan v Australia Test Series'}
# {'match_number': 1, 'name': 'South Africa in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'South Africa in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'New Zealand in West Indies Test Series'}
# {'match_number': 2, 'name': 'New Zealand in West Indies Test Series'}
# {'match_number': 3, 'name': 'New Zealand in West Indies Test Series'}
# {'match_number': 1, 'name': 'Bangladesh in West Indies Test Series'}
# {'match_number': 2, 'name': 'Bangladesh in West Indies Test Series'}
# {'name': 'South Africa tour of Zimbabwe', 'match_number': 2}
# {'match_number': 1, 'name': 'Pakistan v New Zealand Test Series'}
# {'match_number': 2, 'name': 'Pakistan v New Zealand Test Series'}
# {'match_number': 3, 'name': 'Pakistan v New Zealand Test Series'}
# {'match_number': 1, 'name': 'New Zealand in England Test Series'}
# {'match_number': 2, 'name': 'New Zealand in England Test Series'}
# {'match_number': 1, 'name': 'The Ashes'}
# {'match_number': 2, 'name': 'The Ashes'}
# {'match_number': 3, 'name': 'The Ashes'}
# {'match_number': 4, 'name': 'The Ashes'}
# {'match_number': 5, 'name': 'The Ashes'}
# {'match_number': 1, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in New Zealand Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in New Zealand Test Series'}
# {'match_number': 1, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 2, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 3, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 4, 'name': 'Border-Gavaskar Trophy'}
# {'match_number': 1, 'name': 'Zimbabwe in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'Zimbabwe in Bangladesh Test Series'}
# {'match_number': 3, 'name': 'Zimbabwe in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'The Wisden Trophy'}
# {'match_number': 2, 'name': 'The Wisden Trophy'}
# {'match_number': 3, 'name': 'The Wisden Trophy'}
# {'name': "Women's Ashes"}
# {'match_number': 1, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 2, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 3, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 4, 'name': "Basil D'Oliveira Trophy"}
# {'match_number': 1, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 2, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 1, 'name': 'South Africa in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'South Africa in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Bangladesh Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Bangladesh Test Series'}
# {'match_number': 1, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'Pakistan in Sri Lanka Test Series'}
# {'name': 'India tour of Bangladesh', 'match_number': 1}
# {'match_number': 1, 'name': 'Trans-Tasman Trophy', 'sub_name': 'New Zealand in Australia'}
# {'match_number': 2, 'name': 'Trans-Tasman Trophy', 'sub_name': 'New Zealand in Australia'}
# {'match_number': 3, 'name': 'Trans-Tasman Trophy', 'sub_name': 'New Zealand in Australia'}
# {'match_number': 1, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 2, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 3, 'name': 'The Frank Worrell Trophy'}
# {'match_number': 1, 'name': 'India in Sri Lanka Test Series'}
# {'match_number': 2, 'name': 'India in Sri Lanka Test Series'}
# {'match_number': 3, 'name': 'India in Sri Lanka Test Series'}
# {'match_number': 1, 'name': 'Pakistan v England Test Series'}
# {'match_number': 2, 'name': 'Pakistan v England Test Series'}
# {'match_number': 3, 'name': 'Pakistan v England Test Series'}
# {'match_number': 1, 'name': 'Freedom Trophy'}
# {'match_number': 2, 'name': 'Freedom Trophy'}
# {'match_number': 3, 'name': 'Freedom Trophy'}
# {'match_number': 4, 'name': 'Freedom Trophy'}
# {'match_number': 1, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 3, 'name': 'Sri Lanka in England Test Series'}
# {'match_number': 1, 'name': 'Pakistan in England Test Series'}
# {'match_number': 2, 'name': 'Pakistan in England Test Series'}
# {'match_number': 3, 'name': 'Pakistan in England Test Series'}
# {'match_number': 4, 'name': 'Pakistan in England Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in New Zealand Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in New Zealand Test Series'}
# {'match_number': 1, 'name': 'Trans-Tasman Trophy', 'sub_name': 'Australia in New Zealand'}
# {'match_number': 2, 'name': 'Trans-Tasman Trophy', 'sub_name': 'Australia in New Zealand'}
# {'match_number': 1, 'name': 'Sobers/Tissera Trophy'}
# {'match_number': 2, 'name': 'Sobers/Tissera Trophy'}
# {'match_number': 1, 'name': 'New Zealand in South Africa Test Series'}
# {'match_number': 2, 'name': 'New Zealand in South Africa Test Series'}
# {'match_number': 1, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 2, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 3, 'name': 'Sri Lanka in South Africa Test Series'}
# {'match_number': 1, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 2, 'name': 'Warne-Muralitharan Trophy'}
# {'match_number': 3, 'name': 'Warne-Muralitharan Trophy'}

# %%
total_matches = len(all_data)
total_matches
# Out:
# 592

# %%
#umpires_call_true = df2[df2['IsUmpiresCall'] == True]

# %%
for i in range(total_matches):
    for j in range(len(all_data[i]['innings'])):
        inning_number = all_data[i]['innings'][j]
        team = inning_number['team']

# %% [markdown]
# The Umpires_Call decision can never be reversed i.e. 'Upheld' when IsUmpiresCall = True.

# %%
reviews_with_kind = []
review_data_missing = []

for i in range(total_matches):
    for j in range(len(all_data[i]['innings'])):
        inning_number = all_data[i]['innings'][j]
        team = inning_number['team']
        
        for over in inning_number['overs']:
            over_number = str(over['over'])
            for k, delivery in enumerate(over['deliveries']):
                if 'review' in delivery:
                    review_by = 'BattingTeam' if delivery['review']['by'] == team else 'BowlingTeam'
                    
                    #Handle wicket_type logic
                    wicket_type = 'Not Out'
                    wickets = delivery.get('wickets', [])

                    if wickets and isinstance(wickets, list):
                        wicket_type = wickets[0].get('kind', 'No decision')

                    reviews_with_kind.append({
                        'Match_ID': all_data[i]['info'].get('match_type_number'),
                        'Team1': all_data[i]['info']['teams'][0],
                        'Team2': all_data[i]['info']['teams'][1],
                        'Event': all_data[i]['info']['event']['name'],
                        'Year' : all_data[i]['info'].get('season'),
                        'City': all_data[i]['info'].get('city', 'N/A'),
                        'Venue': all_data[i]['info']['venue'],
                        'Innings': j + 1,
                        'Batting_Team': team,
                        'Over': f"{over_number}.{k + 1}",
                        'Bowler': delivery['bowler'],
                        'Batter': delivery['batter'],
                        'ReviewBy': review_by,
                        'IsUmpiresCall': delivery['review'].get('umpires_call', False),
                        'WicketType': wicket_type,
                        'Review_Decision': delivery['review']['decision'],
                        'Umpire_Name': delivery['review'].get('umpire', 'N/A')
                    })

# %%
reviews_with_kind_df = pd.DataFrame(reviews_with_kind)

# %%
reviews_with_kind_df
# Out:
#       Match_ID      Team1         Team2  \
# 0         2230  Australia  South Africa
# 1         2230  Australia  South Africa
# 2         2230  Australia  South Africa
# 3         2230  Australia  South Africa
# 4         2230  Australia  South Africa
# ...        ...        ...           ...
# 5603      2217  Sri Lanka     Australia
# 5604      2217  Sri Lanka     Australia
# 5605      2217  Sri Lanka     Australia
# 5606      2217  Sri Lanka     Australia
# 5607      2217  Sri Lanka     Australia
#
#                                       Event     Year     City  \
# 0     South Africa in Australia Test Series  2016/17    Perth
# 1     South Africa in Australia Test Series  2016/17    Perth
# 2     South Africa in Australia Test Series  2016/17    Perth
# 3     South Africa in Australia Test Series  2016/17    Perth
# 4     South Africa in Australia Test Series  2016/17    Perth
# ...                                     ...      ...      ...
# 5603              Warne-Muralitharan Trophy     2016  Colombo
# 5604              Warne-Muralitharan Trophy     2016  Colombo
# 5605              Warne-Muralitharan Trophy     2016  Colombo
# 5606              Warne-Muralitharan Trophy     2016  Colombo
# 5607              Warne-Muralitharan Trophy     2016  Colombo
#
#                                              Venue  Innings  Batting_Team  \
# 0     Western Australia Cricket Association Ground        1  South Africa
# 1     Western Australia Cricket Association Ground        1  South Africa
# 2     Western Australia Cricket Association Ground        1  South Africa
# 3     Western Australia Cricket Association Ground        2     Australia
# 4     Western Australia Cricket Association Ground        2     Australia
# ...                                            ...      ...           ...
# 5603                  Sinhalese Sports Club Ground        3     Sri Lanka
# 5604                  Sinhalese Sports Club Ground        3     Sri Lanka
# 5605                  Sinhalese Sports Club Ground        4     Australia
# 5606                  Sinhalese Sports Club Ground        4     Australia
# 5607                  Sinhalese Sports Club Ground        4     Australia
#
#       Over        Bowler        Batter     ReviewBy  IsUmpiresCall WicketType  \
# 0     12.2     PM Siddle     JP Duminy  BattingTeam          False     caught
# 1     50.2      MA Starc     Q de Kock  BowlingTeam          False    Not Out
# 2     55.4  JR Hazlewood     Q de Kock  BowlingTeam          False    Not Out
# 3     41.3    KA Maharaj     SPD Smith  BattingTeam          False        lbw
# 4     46.5  VD Philander      SE Marsh  BattingTeam          False        lbw
# ...    ...           ...           ...          ...            ...        ...
# 5603  26.3    JM Holland      JK Silva  BowlingTeam          False    Not Out
# 5604  79.3       NM Lyon  LD Chandimal  BowlingTeam          False        lbw
# 5605  17.3    MDK Perera     DA Warner  BowlingTeam          False    Not Out
# 5606  17.4    MDK Perera     DA Warner  BowlingTeam          False    Not Out
# 5607  44.1  HMRKB Herath       NM Lyon  BattingTeam          False        lbw
#
#      Review_Decision  Umpire_Name
# 0        struck down     NJ Llong
# 1        struck down     NJ Llong
# 2        struck down    Aleem Dar
# 3        struck down    Aleem Dar
# 4        struck down     NJ Llong
# ...              ...          ...
# 5603     struck down       S Ravi
# 5604          upheld  CB Gaffaney
# 5605     struck down       S Ravi
# 5606     struck down  CB Gaffaney
# 5607     struck down       S Ravi
#
# [5608 rows x 17 columns]

# %%
reviews_with_kind_df.to_excel('reviews_with_kind.xlsx', sheet_name='Reviews', index=False)

# %%
reviews_with_kind_df['Opposition'] = np.where(
    reviews_with_kind_df['Team1'] == reviews_with_kind_df['Batting_Team'],
    reviews_with_kind_df['Team2'],
    reviews_with_kind_df['Team1']
)

# %%
#Move 'Opposition' to the 9th position beside Batting_Team
cols = list(reviews_with_kind_df.columns)
cols.insert(9, cols.pop(cols.index('Opposition')))
reviews_with_kind_df = reviews_with_kind_df[cols]

# %%
reviews_with_kind_df
# Out:
#       Match_ID      Team1         Team2  \
# 0         2230  Australia  South Africa
# 1         2230  Australia  South Africa
# 2         2230  Australia  South Africa
# 3         2230  Australia  South Africa
# 4         2230  Australia  South Africa
# ...        ...        ...           ...
# 5603      2217  Sri Lanka     Australia
# 5604      2217  Sri Lanka     Australia
# 5605      2217  Sri Lanka     Australia
# 5606      2217  Sri Lanka     Australia
# 5607      2217  Sri Lanka     Australia
#
#                                       Event     Year     City  \
# 0     South Africa in Australia Test Series  2016/17    Perth
# 1     South Africa in Australia Test Series  2016/17    Perth
# 2     South Africa in Australia Test Series  2016/17    Perth
# 3     South Africa in Australia Test Series  2016/17    Perth
# 4     South Africa in Australia Test Series  2016/17    Perth
# ...                                     ...      ...      ...
# 5603              Warne-Muralitharan Trophy     2016  Colombo
# 5604              Warne-Muralitharan Trophy     2016  Colombo
# 5605              Warne-Muralitharan Trophy     2016  Colombo
# 5606              Warne-Muralitharan Trophy     2016  Colombo
# 5607              Warne-Muralitharan Trophy     2016  Colombo
#
#                                              Venue  Innings  Batting_Team  \
# 0     Western Australia Cricket Association Ground        1  South Africa
# 1     Western Australia Cricket Association Ground        1  South Africa
# 2     Western Australia Cricket Association Ground        1  South Africa
# 3     Western Australia Cricket Association Ground        2     Australia
# 4     Western Australia Cricket Association Ground        2     Australia
# ...                                            ...      ...           ...
# 5603                  Sinhalese Sports Club Ground        3     Sri Lanka
# 5604                  Sinhalese Sports Club Ground        3     Sri Lanka
# 5605                  Sinhalese Sports Club Ground        4     Australia
# 5606                  Sinhalese Sports Club Ground        4     Australia
# 5607                  Sinhalese Sports Club Ground        4     Australia
#
#         Opposition  Over        Bowler        Batter     ReviewBy  \
# 0        Australia  12.2     PM Siddle     JP Duminy  BattingTeam
# 1        Australia  50.2      MA Starc     Q de Kock  BowlingTeam
# 2        Australia  55.4  JR Hazlewood     Q de Kock  BowlingTeam
# 3     South Africa  41.3    KA Maharaj     SPD Smith  BattingTeam
# 4     South Africa  46.5  VD Philander      SE Marsh  BattingTeam
# ...            ...   ...           ...           ...          ...
# 5603     Australia  26.3    JM Holland      JK Silva  BowlingTeam
# 5604     Australia  79.3       NM Lyon  LD Chandimal  BowlingTeam
# 5605     Sri Lanka  17.3    MDK Perera     DA Warner  BowlingTeam
# 5606     Sri Lanka  17.4    MDK Perera     DA Warner  BowlingTeam
# 5607     Sri Lanka  44.1  HMRKB Herath       NM Lyon  BattingTeam
#
#       IsUmpiresCall WicketType Review_Decision  Umpire_Name
# 0             False     caught     struck down     NJ Llong
# 1             False    Not Out     struck down     NJ Llong
# 2             False    Not Out     struck down    Aleem Dar
# 3             False        lbw     struck down    Aleem Dar
# 4             False        lbw     struck down     NJ Llong
# ...             ...        ...             ...          ...
# 5603          False    Not Out     struck down       S Ravi
# 5604          False        lbw          upheld  CB Gaffaney
# 5605          False    Not Out     struck down       S Ravi
# 5606          False    Not Out     struck down  CB Gaffaney
# 5607          False        lbw     struck down       S Ravi
#
# [5608 rows x 18 columns]
